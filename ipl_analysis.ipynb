# %%
import pandas as pd
import numpy as np

# %%
ball = pd.read_csv("C:\\Users\prabi\Downloads\Cricket\IPL 2008 to 2022 All Match Dataset\IPL_Ball_by_Ball_2008_2022.csv")

# %%
matches = pd.read_csv("C:\\Users\prabi\Downloads\Cricket\IPL 2008 to 2022 All Match Dataset\IPL_Matches_2008_2022.csv")

# %%
matches.head()
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198    Kolkata  2022-05-25   2022   Eliminator
# 3  1312197    Kolkata  2022-05-24   2022  Qualifier 1
# 4  1304116     Mumbai  2022-05-22   2022           70
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
# 3             Rajasthan Royals        Gujarat Titans
# 4          Sunrisers Hyderabad          Punjab Kings
#
#                               Venue            TossWinner TossDecision  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field
# ...

# %%
matches.isnull().sum()
# Out:
# ID                   0
# City                51
# Date                 0
# Season               0
# MatchNumber          0
# Team1                0
# Team2                0
# Venue                0
# TossWinner           0
# TossDecision         0
# SuperOver            4
# WinningTeam          4
# WonBy                0
# Margin              18
# method             931
# Player_of_Match      4
# Team1Players         0
# Team2Players         0
# Umpire1              0
# Umpire2              0
# dtype: int64

# %%
matches.shape
# Out:
# (950, 20)

# %%
df = pd.merge(ball, matches, how = 'right', on ='ID' )

# %%
ball.shape
# Out:
# (225954, 17)

# %%
df.shape
# Out:
# (225954, 36)

# %%
df.columns
# Out:
# Index(['ID', 'innings', 'overs', 'ballnumber', 'batter', 'bowler',
#        'non-striker', 'extra_type', 'batsman_run', 'extras_run', 'total_run',
#        'non_boundary', 'isWicketDelivery', 'player_out', 'kind',
#        'fielders_involved', 'BattingTeam', 'City', 'Date', 'Season',
#        'MatchNumber', 'Team1', 'Team2', 'Venue', 'TossWinner', 'TossDecision',
#        'SuperOver', 'WinningTeam', 'WonBy', 'Margin', 'method',
#        'Player_of_Match', 'Team1Players', 'Team2Players', 'Umpire1',
#        'Umpire2'],
#       dtype='object')

# %%
df.head().T
# Out:
#                                                                    0  \
# ID                                                           1312200
# innings                                                            1
# overs                                                              0
# ballnumber                                                         1
# batter                                                   YBK Jaiswal
# bowler                                                Mohammed Shami
# non-striker                                               JC Buttler
# extra_type                                                       NaN
# batsman_run                                                        0
# extras_run                                                         0
# total_run                                                          0
# non_boundary                                                       0
# isWicketDelivery                                                   0
# ...

# %%
df1 = df.drop(columns = ['innings', 'overs', 'ballnumber','extra_type', 'batsman_run', 'extras_run','player_out', 'kind',
       'fielders_involved','City', 'Date', 'Season',
       'MatchNumber','TossWinner', 'TossDecision',
       'SuperOver', 'WinningTeam', 'WonBy', 'Margin', 'method',
       'Player_of_Match', 'Umpire1',
       'Umpire2', 'non_boundary',
       'isWicketDelivery', 'BattingTeam', 'Team1', 'Team2','bowler',
       'non-striker'])

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 225954 entries, 0 to 225953
# Data columns (total 6 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   ID            225954 non-null  int64
#  1   batter        225954 non-null  object
#  2   total_run     225954 non-null  int64
#  3   Venue         225954 non-null  object
#  4   Team1Players  225954 non-null  object
#  5   Team2Players  225954 non-null  object
# dtypes: int64(2), object(4)
# memory usage: 12.1+ MB

# %%
df1
# Out:
#              ID       batter  total_run                             Venue  \
# 0       1312200  YBK Jaiswal          0  Narendra Modi Stadium, Ahmedabad
# 1       1312200  YBK Jaiswal          1  Narendra Modi Stadium, Ahmedabad
# 2       1312200   JC Buttler          1  Narendra Modi Stadium, Ahmedabad
# 3       1312200  YBK Jaiswal          0  Narendra Modi Stadium, Ahmedabad
# 4       1312200  YBK Jaiswal          0  Narendra Modi Stadium, Ahmedabad
# ...         ...          ...        ...                               ...
# 225949   335982      P Kumar          1             M Chinnaswamy Stadium
# 225950   335982     SB Joshi          1             M Chinnaswamy Stadium
# 225951   335982      P Kumar          0             M Chinnaswamy Stadium
# 225952   335982     SB Joshi          1             M Chinnaswamy Stadium
# 225953   335982     SB Joshi          0             M Chinnaswamy Stadium
#
#                                              Team1Players  \
# ...

# %%
def opponent_team(merged):
    if merged['batter'] in merged['Team1Players']:
        return merged['Team2Players']
    else:
        return merged['Team1Players']

# %%
temp_df = df1[df1['ID'] == id[0]]
join =temp_df.groupby('batter').sum('total_run')
merged = pd.merge(temp_df, join, how = 'left', on ='batter')
merged.drop(columns = ['total_run_x', 'ID_y'], inplace = True)
merged.drop_duplicates(inplace = True)
merged['opponent_team'] = merged.apply(opponent_team, axis=1)
merged.drop(columns = ['Team1Players', 'Team2Players'], inplace = True)

# %%
merged
# Out:
#         ID_x        batter                             Venue  total_run_y  \
# 0    1312200   YBK Jaiswal  Narendra Modi Stadium, Ahmedabad           23
# 2    1312200    JC Buttler  Narendra Modi Stadium, Ahmedabad           39
# 26   1312200     SV Samson  Narendra Modi Stadium, Ahmedabad           14
# 50   1312200    D Padikkal  Narendra Modi Stadium, Ahmedabad            3
# 71   1312200    SO Hetmyer  Narendra Modi Stadium, Ahmedabad           11
# 73   1312200      R Ashwin  Narendra Modi Stadium, Ahmedabad            6
# 91   1312200       R Parag  Narendra Modi Stadium, Ahmedabad           15
# 95   1312200      TA Boult  Narendra Modi Stadium, Ahmedabad           11
# 105  1312200      OC McCoy  Narendra Modi Stadium, Ahmedabad            8
# 120  1312200       WP Saha  Narendra Modi Stadium, Ahmedabad            5
# 123  1312200  Shubman Gill  Narendra Modi Stadium, Ahmedabad           46
# 130  1312200       MS Wade  Narendra Modi Stadium, Ahmedabad           13
# ...
